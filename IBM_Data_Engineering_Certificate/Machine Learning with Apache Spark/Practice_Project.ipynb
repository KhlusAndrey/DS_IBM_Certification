# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMSkillsNetworkBD0231ENCoursera2789-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# ## Practice Project - Create a machine learning pipeline for a regression project

# %% [markdown]
# Estimated time needed: **90** minutes

# %% [markdown]
# ## Scenario

# %% [markdown]
# You are a data engineer at a data analytics consulting company. Your company prides itself in being able to efficiently handle huge datasets. Data scientists in your office need to work with different algorithms and data in different formats. While they are good at Machine Learning, they count on you to be able do ETL jobs and build ML pipelines.

# %% [markdown]
# ## Objectives
#
# In this 4 part assignment you will:
#
# - Part 1 ETL
#   - Load a csv dataset
#   - Remove duplicates if any
#   - Drop rows with null values if any
#   - Make transformations
#   - Store the cleaned data in parquet format
# - Part 2 Machine Learning Pipeline creation
#   - Create a machine learning pipeline for prediction
# - Part 3 Model evaluation
#   - Evaluate the model using metrics
#   - Print the intercept and the coefficients
# - Part 4 Model Persistance
#   - Cave the model for future production use
#   - Load and verify the stored model

# %% [markdown]
# ## Datasets
#
# In this lab you will be using dataset(s):
#
#  - Modified version of car mileage dataset. Original dataset available at https://archive.ics.uci.edu/ml/datasets/auto+mpg

# %% [markdown]
# ----

# %% [markdown]
# ## Setup

# %% [markdown]
# For this lab, we will be using the following libraries:
#
# *   [`PySpark`](https://spark.apache.org/docs/latest/api/python/index.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMSkillsNetworkBD0231ENCoursera2789-2023-01-01) for connecting to the Spark Cluster

# %% [markdown]
# ### Installing Required Libraries
#
# Spark Cluster is pre-installed in the Skills Network Labs environment. However, you need libraries like pyspark and findspark to
#  connect to this cluster.

# %% [markdown]
# The following required libraries are __not__ pre-installed in the Skills Network Labs environment. __You will need to run the following cell__ to install them:

# %%
# !pip install pyspark==3.1.2 -q
# !pip install findspark -q

# %% [markdown]
# ### Importing Required Libraries
#
# _We recommend you import all required libraries in one place (here):_

# %%
# You can also use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

# FindSpark simplifies the process of using Apache Spark with Python

import findspark
findspark.init()

# %% [markdown]
# ## Part 1 - ETL

# %% [markdown]
# ### Task 1 - Import required libraries

# %%
#your code goes here
from pyspark.sql import SparkSession
from pyspark.ml import Pipeline
from pyspark.ml.pipeline import PipelineModel
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import LinearRegression
from pyspark.ml.feature import StringIndexer
from pyspark.ml.feature import StandardScaler
from tqdm import tqdm

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Import all the required libraries
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# from pyspark.sql import SparkSession
# from pyspark.ml import Pipeline
# from pyspark.ml.pipeline import PipelineModel
# from pyspark.ml.feature import VectorAssembler
# from pyspark.ml.regression import LinearRegression
# from pyspark.ml.feature import StringIndexer
# from pyspark.ml.feature import StandardScaler
#
# ```
#
# </details>

# %% [markdown]
# ### Task 2 - Create a spark session

# %%
#Create SparkSession

spark = SparkSession.builder.appName("Practice Project").getOrCreate()
# Out:
# 23/11/09 08:45:03 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the SparkSession.builder
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# spark = SparkSession.builder.appName("Practice Project").getOrCreate()
# ```
#
# </details>

# %% [markdown]
# ### Task 3 - Load the csv file into a dataframe

# %% [markdown]
# Download the data file

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-BD0231EN-Coursera/datasets/mpg-raw.csv
# Out:
# --2023-11-09 08:45:15--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-BD0231EN-Coursera/datasets/mpg-raw.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14354 (14K) [text/csv]
# Saving to: ‘mpg-raw.csv’
#
# mpg-raw.csv         100%[===================>]  14.02K  --.-KB/s    in 0s
#
# 2023-11-09 08:45:15 (31.3 MB/s) - ‘mpg-raw.csv’ saved [14354/14354]

# %% [markdown]
# Load the dataset into the spark dataframe

# %%
# Load dataset
df = spark.read.csv("mpg-raw.csv", header=True, inferSchema=True)

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use  spark.read.csv
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# df = spark.read.csv("mpg-raw.csv", header=True, inferSchema=True)
#
# ```
#
# </details>

# %% [markdown]
# ### Task 4 - Print top 5 rows of the dataset

# %%
#your code goes here
df.show(5)
# Out:
# +----+---------+-----------+----------+------+----------+----+--------+
# | MPG|Cylinders|Engine Disp|Horsepower|Weight|Accelerate|Year|  Origin|
# +----+---------+-----------+----------+------+----------+----+--------+
# |46.6|        4|       86.0|        65|  2110|      17.9|  80|Japanese|
# |44.6|        4|       91.0|        67|  1850|      13.8|  80|Japanese|
# |44.3|        4|       90.0|        48|  2085|      21.7|  80|European|
# |44.0|        4|       97.0|        52|  2130|      24.6|  82|European|
# |43.4|        4|       90.0|        48|  2335|      23.7|  80|European|
# +----+---------+-----------+----------+------+----------+----+--------+
# only showing top 5 rows

# %% [markdown]
# ### Task 5 - Print the number of cars in each Origin

# %%
#your code goes here
df.groupBy('Origin').count().orderBy('count').show()
# Out:
# [Stage 26:=========================================>            (152 + 9) / 200]
# +--------+-----+
# |  Origin|count|
# +--------+-----+
# |    null|    1|
# |European|   70|
# |Japanese|   88|
# |American|  247|
# +--------+-----+

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use  df.groupBy
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# df.groupBy('Origin').count().orderBy('count').show()
# ```
#
# </details>

# %% [markdown]
# ### Task 6 - Print the total number of rows in the dataset

# %%
df.printSchema()
# Out:
# root
#  |-- MPG: double (nullable = true)
#  |-- Cylinders: integer (nullable = true)
#  |-- Engine Disp: double (nullable = true)
#  |-- Horsepower: integer (nullable = true)
#  |-- Weight: integer (nullable = true)
#  |-- Accelerate: double (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Origin: string (nullable = true)

# %%
df.summary().show()
# Out:
# +-------+-----------------+------------------+------------------+------------------+-----------------+------------------+------------------+--------+
# |summary|              MPG|         Cylinders|       Engine Disp|        Horsepower|           Weight|        Accelerate|              Year|  Origin|
# +-------+-----------------+------------------+------------------+------------------+-----------------+------------------+------------------+--------+
# |  count|              405|               405|               405|               405|              405|               405|               406|     405|
# |   mean|23.94469135802469|  5.42962962962963| 191.4111111111111|103.34320987654321|2947.427160493827|15.578024691358014| 76.13793103448276|    null|
# | stddev|8.150578714559307|1.6968553066756082|104.57390915160208|38.405834882704035| 851.922890663656| 2.733254334454551|3.7218991110403423|    null|
# |    min|              9.0|                 3|              68.0|                46|             1613|               8.0|                70|American|
# |    25%|             17.5|                 4|              98.0|                75|             2200|              13.9|                73|    null|
# |    50%|             23.0|                 4|             141.0|                92|             2745|              15.5|                76|    null|
# |    75%|             30.0|                 8|             262.0|               122|             3574|              17.1|                79|    null|
# |    max|             46.6|                 8|             455.0|               230|             5140|              24.8|                82|Japanese|
# +-------+-----------------+------------------+------------------+------------------+-----------------+------------------+------------------+--------+

# %%
print((df.count(), len(df.columns)))
# Out:
# (406, 8)

# %%
pdf = df.toPandas()

# %%
pdf.isna().sum()
# Out:
# MPG            1
# Cylinders      1
# Engine Disp    1
# Horsepower     1
# Weight         1
# Accelerate     1
# Year           0
# Origin         1
# dtype: int64

# %%
pdf[pdf.isnull().any(axis=1)]
# Out:
#       MPG  Cylinders  Engine Disp  Horsepower  Weight  Accelerate  Year  \
# 62   33.5        4.0        151.0        90.0  2556.0        13.2    79
# 71    NaN        4.0         97.0        67.0  2065.0        17.8    81
# 74   32.0        4.0         83.0         NaN  2003.0        19.0    74
# 79   32.0        4.0          NaN        96.0  2665.0        13.9    82
# 94   30.7        6.0        145.0        76.0     NaN        19.6    81
# 103  30.0        NaN        135.0        84.0  2385.0        12.9    81
# 121  28.0        4.0        116.0        90.0  2123.0         NaN    71
#
#        Origin
# 62       None
# 71   Japanese
# 74   Japanese
# 79   Japanese
# 94   European
# 103  American
# 121  European

# %%
#your code goes here
rowcount1 = df.count()
print(rowcount1)
# Out:
# 406

# %% [markdown]
# ### Task 7 - Drop all the duplicate rows from the dataset

# %%
#your code goes here
df = df.dropDuplicates()

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use  df.dropDuplicates
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# df = df.dropDuplicates()
# ```
#
# </details>

# %%
rowcount2 = df.count()

# %% [markdown]
# ### Task 8 - Print the total number of rows in the dataset

# %%
#your code goes here
# rowcount2 = #TODO
print(rowcount2)
# Out:
# 392

# %% [markdown]
# ### Task 9 - Drop all the rows that contain null values from the dataset

# %%
#your code goes here
df = df.dropna()

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use df.dropna
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# df=df.dropna()
# ```
#
# </details>

# %% [markdown]
# ### Task 10 - Print the total number of rows in the dataset

# %%
#your code goes here
rowcount3 = df.count()
print(rowcount3)
# Out:
# 385

# %% [markdown]
# ### Task 11 - Rename the column "Engine Disp" to "Engine_Disp"Drop

# %%
#your code goes here

df = df.withColumnRenamed("Engine Disp", "Engine_Disp")

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use df.withColumnRenamed
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# df = df.withColumnRenamed("Engine Disp","Engine_Disp")
# ```
#
# </details>

# %% [markdown]
# ### Task 12 - Save the dataframe in parquet format, name the file as "mpg-cleaned.parquet"

# %%
#your code goes here
df.write.parquet("mpg-cleaned.parquet")
# Out:
# [Stage 41:=======>                                               (28 + 8) / 200]23/11/09 09:47:55 WARN hadoop.MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 23/11/09 09:47:55 WARN hadoop.MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 23/11/09 09:47:56 WARN hadoop.MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use df.write.parquet
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# df.write.parquet("mpg-cleaned.parquet")
# ```
#
# </details>

# %% [markdown]
# #### Part 1 - Evaluation

# %% [markdown]
# Run the code cell below.<br>
# If the code throws up any errors, go back and review the code you have written.

# %%
print("Part 1 - Evaluation")

print("Total rows = ", rowcount1)
print("Total rows after dropping duplicate rows = ", rowcount2)
print("Total rows after dropping duplicate rows and rows with null values = ", rowcount3)
print("Renamed column name = ", df.columns[2])

import os

print("mpg-cleaned.parquet exists :", os.path.isdir("mpg-cleaned.parquet"))
# Out:
# Part 1 - Evaluation
# Total rows =  406
# Total rows after dropping duplicate rows =  392
# Total rows after dropping duplicate rows and rows with null values =  385
# Renamed column name =  Engine_Disp
# mpg-cleaned.parquet exists : True

# %% [markdown]
# ## Part - 2 Machine Learning Pipeline creation

# %% [markdown]
# ### Task 1 - Load data from "mpg-cleaned.parquet" into a dataframe

# %%
#your code goes here

df = spark.read.parquet("mpg-cleaned.parquet")
rowcount4 = df.count()

# %%
rowcount4
# Out:
# 385

# %%
#show top 5 rows
#your code goes here
df.show(5)
# Out:
# +----+---------+-----------+----------+------+----------+----+--------+
# | MPG|Cylinders|Engine_Disp|Horsepower|Weight|Accelerate|Year|  Origin|
# +----+---------+-----------+----------+------+----------+----+--------+
# |32.2|        4|      108.0|        75|  2265|      15.2|  80|Japanese|
# |28.0|        4|      107.0|        86|  2464|      15.5|  76|European|
# |26.0|        4|      156.0|        92|  2585|      14.5|  82|American|
# |25.0|        4|      104.0|        95|  2375|      17.5|  70|European|
# |25.0|        4|      140.0|        75|  2542|      17.0|  74|American|
# +----+---------+-----------+----------+------+----------+----+--------+
# only showing top 5 rows

# %%
#print the schema of the dataframe
#your code goes here
df.printSchema()
# Out:
# root
#  |-- MPG: double (nullable = true)
#  |-- Cylinders: integer (nullable = true)
#  |-- Engine_Disp: double (nullable = true)
#  |-- Horsepower: integer (nullable = true)
#  |-- Weight: integer (nullable = true)
#  |-- Accelerate: double (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Origin: string (nullable = true)

# %% [markdown]
# ### Task 2 - Define the StringIndexer pipeline stage

# %%
# Stage - 1 Using StringIndexer convert the string column "Origin" into "OriginIndex"
indexer = StringIndexer(inputCol="Origin", outputCol="OriginIndex")

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use StringIndexer class
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# indexer = StringIndexer(inputCol="Origin", outputCol="OriginIndex")
# ```
#
# </details>

# %% [markdown]
# ### Task 3 - Define the VectorAssembler pipeline stage

# %%
# Stage 2 - assemble the input columns 'Cylinders','Engine_Disp','Horsepower','Weight','Accelerate','Year' into a single column "features"
inputCols = ['Cylinders', 'Engine_Disp', 'Horsepower', 'Weight', 'Accelerate', 'Year']
assembler = VectorAssembler(inputCols=inputCols, outputCol="features")

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the VectorAssembler class
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# assembler = VectorAssembler(inputCols=['Cylinders','Engine_Disp','Horsepower','Weight','Accelerate','Year'], outputCol="features")
# ```
#
# </details>

# %% [markdown]
# ### Task 4 - Define the StandardScaler pipeline stage

# %%
# Stage 3 - scale the "features" using standard scaler and store in "scaledFeatures" column
scaler = StandardScaler(inputCol="features", outputCol="scaledFeatures")

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the StandardScaler class
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# scaler = StandardScaler(inputCol="features", outputCol="scaledFeatures")
#
# ```
#
# </details>

# %% [markdown]
# ### Task 5 - Define the StandardScaler pipeline stage

# %%
# Stage 4 - Create a LinearRegression stage to predict "MPG"

lr = LinearRegression(featuresCol="features", labelCol="MPG")

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the LinearRegression class
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# lr = LinearRegression(featuresCol="features", labelCol="MPG")
# ```
#
# </details>

# %% [markdown]
# ### Task 6 - Build the pipeline

# %%
# Build a pipeline using the above four stages

pipeline = Pipeline(stages=[indexer, assembler, scaler, lr])

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the Pipeline class
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# pipeline = Pipeline(stages=[indexer,assembler, scaler, lr])
# ```
#
# </details>

# %% [markdown]
# ### Task 7 - Split the data

# %%
# Split the data into training and testing sets with 70:30 split. Use 42 as seed
(trainingData, testingData) = df.randomSplit([0.7, 0.3], seed=42)

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the randomSplit method
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# (trainingData, testingData) = df.randomSplit([0.7, 0.3], seed=42)
# ```
#
# </details>

# %% [markdown]
# ### Task 8 - Fit the pipeline

# %%
# Fit the pipeline using the training data

pipelineModel = pipeline.fit(trainingData)
# Out:
# 23/11/09 10:02:01 WARN util.Instrumentation: [b5833e8c] regParam is zero, which might cause numerical instability and overfitting.
# [Stage 51:>                                                         (0 + 8) / 8]23/11/09 10:02:03 WARN netlib.BLAS: Failed to load implementation from: com.github.fommil.netlib.NativeSystemBLAS
# 23/11/09 10:02:03 WARN netlib.BLAS: Failed to load implementation from: com.github.fommil.netlib.NativeRefBLAS
# 23/11/09 10:02:03 WARN netlib.LAPACK: Failed to load implementation from: com.github.fommil.netlib.NativeSystemLAPACK
# 23/11/09 10:02:03 WARN netlib.LAPACK: Failed to load implementation from: com.github.fommil.netlib.NativeRefLAPACK

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the pipeline.fit method
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# pipelineModel = pipeline.fit(trainingData)
# ```
#
# </details>

# %% [markdown]
# #### Part 2 - Evaluation

# %% [markdown]
# Run the code cell below.<br>
# If the code throws up any errors, go back and review the code you have written.

# %%
print("Part 2 - Evaluation")
print("Total rows = ", rowcount4)
ps = [str(x).split("_")[0] for x in pipeline.getStages()]

print("Pipeline Stage 1 = ", ps[0])
print("Pipeline Stage 2 = ", ps[1])
print("Pipeline Stage 3 = ", ps[2])

print("Label column = ", lr.getLabelCol())
# Out:
# Part 2 - Evaluation
# Total rows =  385
# Pipeline Stage 1 =  StringIndexer
# Pipeline Stage 2 =  VectorAssembler
# Pipeline Stage 3 =  StandardScaler
# Label column =  MPG

# %% [markdown]
# ## Part 3 - Model Evaluation

# %% [markdown]
# ### Task 1 - Predict using the model

# %%
# Make predictions on testing data
predictions = pipelineModel.transform(testingData)

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the transform method of the model
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# predictions = pipelineModel.transform(testingData)
# ```
#
# </details>

# %% [markdown]
# ### Task 2 - Print the MSE

# %%
#Your code goes here
from pyspark.ml.evaluation import RegressionEvaluator

evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="MPG", metricName="mse")
mse = evaluator.evaluate(predictions)
print(mse)
# Out:
# [Stage 58:=======>                                                  (1 + 7) / 8]
# 10.899168410636353

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the RegressionEvaluator
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# from pyspark.ml.evaluation import RegressionEvaluator
#
# evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="MPG", metricName="mse")
# mse = evaluator.evaluate(predictions)
# print(mse)
#
# ```
#
# </details>

# %% [markdown]
# ### Task 3 - Print the MAE

# %%
#Your code goes here

evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="MPG", metricName="mae")
mae = evaluator.evaluate(predictions)
print(mae)
# Out:
# [Stage 60:=======>                                                  (1 + 7) / 8]
# 2.6256840060950886

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the RegressionEvaluator
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="MPG", metricName="mae")
# mae = evaluator.evaluate(predictions)
# print(mae)
#
# ```
#
# </details>

# %% [markdown]
# ### Task 4 - Print the R-Squared(R2)

# %%
#Your code goes here

evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="MPG", metricName="r2")
r2 = evaluator.evaluate(predictions)
print(r2)
# Out:
# [Stage 62:==============>                                           (2 + 6) / 8]
# 0.8202762026606922

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the RegressionEvaluator
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="MPG", metricName="r2")
# r2 = evaluator.evaluate(predictions)
# print(r2)
# ```
#
# </details>

# %% [markdown]
# #### Part 3 - Evaluation

# %% [markdown]
# Run the code cell below.<br>
# If the code throws up any errors, go back and review the code you have written.

# %%
print("Part 3 - Evaluation")

print("Mean Squared Error = ", round(mse,2))
print("Mean Absolute Error = ", round(mae,2))
print("R Squared = ", round(r2,2))

lrModel = pipelineModel.stages[-1]

print("Intercept = ", round(lrModel.intercept, 2))
# Out:
# Part 3 - Evaluation
# Mean Squared Error =  10.9
# Mean Absolute Error =  2.63
# R Squared =  0.82
# Intercept =  -13.9

# %% [markdown]
# ## Part 4 - Model persistance

# %% [markdown]
# ### Task 1 - Save the model to the path "Practice_Project"

# %%
# Save the pipeline model
# your code goes here

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the model.write().save method
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# pipelineModel.write().save("Practice_Project")
# ```
#
# </details>

# %% [markdown]
# ### Task 2 - Load the model from the path "Practice_Project"

# %%
# Load the pipeline model
# your code goes here

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the load method of the model
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# loadedPipelineModel = PipelineModel.load("Practice_Project")
# ```
#
# </details>

# %% [markdown]
# ### Task 3 - Make predictions using the loaded model on the test data

# %%
# Use the loaded pipeline model for predictions
# your code goes here

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the transform method
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# predictions = loadedPipelineModel.transform(testingData)
# ```
#
# </details>

# %% [markdown]
# ### Task 4 - Show the predictions

# %%
# your code goes here

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# Use the the select method of the dataframe
#
# </details>

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# predictions.select("MPG","prediction").show()
# ```
#
# </details>

# %% [markdown]
# #### Part 4 - Evaluation

# %% [markdown]
# Run the code cell below.<br>
# If the code throws up any errors, go back and review the code you have written.

# %%
print("Part 4 - Evaluation")

loadedmodel = loadedPipelineModel.stages[-1]
totalstages = len(loadedPipelineModel.stages)
inputcolumns = loadedPipelineModel.stages[1].getInputCols()

print("Number of stages in the pipeline = ", totalstages)
for i,j in zip(inputcolumns, loadedmodel.coefficients):
    print(f"Coefficient for {i} is {round(j,4)}")

# %% [markdown]
# ### Task 5 - Stop Spark Session

# %%
spark.stop()

# %% [markdown]
# Congratulations!! you have successfully finished the practice project.

# %% [markdown]
# ## Authors

# %% [markdown]
# [Ramesh Sannareddy](https://www.linkedin.com/in/rsannareddy/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMBD0231ENSkillsNetwork866-2023-01-01)

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# ## Change Log

# %% [markdown]
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2023-05-26|0.1|Ramesh Sannareddy|Initial Version Created|

# %% [markdown]
# Copyright © 2023 IBM Corporation. All rights reserved.
